# %% [markdown]
# # ADK with MCP Integration
#
# **This notebook requires LOCAL execution** (Jupyter Lab, VS Code, PyCharm, etc.). MCP servers communicate via stdio, which is not compatible with Google Colab's I/O system.
#
# In this notebook, you'll learn how to connect ADK agents to external data sources using the **Model Context Protocol (MCP)**. This combines everything from the previous notebooks into a complete three-layer architecture. We'll cover:
#
# - The three-layer AI agent stack: LLM (reasoning) + ADK (orchestration) + MCP (data connectivity)
# - Creating MCP servers that expose data and tools
# - Connecting ADK agents to MCP servers using `McpToolset`
# - Building a complete multi-agent system with real data access
#
# We'll build a full IT support system where a coordinator routes requests to specialists, and each specialist accesses its data through a dedicated MCP server.

# %% [markdown]
# # The AI Agent Stack
#
# The complete system has three layers, each with a clear responsibility:
#
# ```
# ┌─────────────────────────────────────────────┐
# │  Layer 1: LLM Provider (OpenAI)             │  Reasoning & Intelligence
# │  gpt-5-nano, gpt-4o, etc.                   │
# └─────────────────────────────────────────────┘
#                     ▲
# ┌─────────────────────────────────────────────┐
# │  Layer 2: ADK (Agent Development Kit)       │  Orchestration & Coordination
# │  Multi-agent systems, workflows, tools      │
# └─────────────────────────────────────────────┘
#                     ▲
# ┌─────────────────────────────────────────────┐
# │  Layer 3: MCP (Model Context Protocol)      │  Data Connectivity
# │  Standardized interface to databases,       │
# │  APIs, files, and other data sources        │
# └─────────────────────────────────────────────┘
# ```
#
# This separation means you can swap any layer independently: change the LLM provider without touching your data layer, add new data sources without changing your agent logic, or reorganize your agents without modifying your MCP servers.

# %% [markdown]
# # Setup
#
# Before we begin, let's install the necessary libraries, configure API access, and import all required packages.
#
# ## Install Dependencies
#
# Run the cell below to install all dependencies for this notebook.

# %%
# Install required packages
# !pip install -q google-adk==1.28.0 litellm==1.83.4 openai==2.30.0 python-dotenv==1.0.1 nest-asyncio==1.6.0 deprecated==1.2.18 mcp==1.27.0 httpx==0.28.1 2>/dev/null

print("✅ Packages installed successfully!")

# %% [markdown]
# ## API Key Configuration
#
# Since this notebook runs locally (not on Colab), we first try to load the API key from the `OPENAI_API_KEY` environment variable. If that's not set, you'll be prompted to enter it manually.
#
# Run the cell below to configure authentication:

# %%
import os

try:
    OPENAI_API_KEY = os.getenv('OPENAI_API_KEY')
    if OPENAI_API_KEY:
        print("✅ API key loaded from environment variable")
    else:
        raise ValueError("No environment variable found")
except:
    from getpass import getpass
    OPENAI_API_KEY = getpass("Enter your OpenAI API Key: ")

os.environ["OPENAI_API_KEY"] = OPENAI_API_KEY

if not OPENAI_API_KEY or OPENAI_API_KEY.strip() == "":
    raise ValueError("❌ ERROR: No API key provided!")

print("✅ Authentication configured!")

OPENAI_MODEL = "gpt-5-nano"
print(f"Selected Model: {OPENAI_MODEL}")

# %% [markdown]
# ## Import Libraries
#
# In addition to the standard ADK imports, we import `McpToolset` and its connection classes. These let ADK agents discover and call tools exposed by MCP servers.

# %%
# Core ADK imports
from google.adk.agents import LlmAgent
from google.adk.runners import Runner
from google.adk.sessions import InMemorySessionService
from google.adk.models.lite_llm import LiteLlm
from google.genai import types

# MCP integration imports
from google.adk.tools.mcp_tool.mcp_toolset import McpToolset
from google.adk.tools.mcp_tool.mcp_session_manager import StdioConnectionParams
from mcp import StdioServerParameters

# System imports
import os
import sys
import asyncio
from pathlib import Path
import warnings
from contextlib import redirect_stdout, redirect_stderr
from io import StringIO

# Enable nested asyncio for local execution
import nest_asyncio
nest_asyncio.apply()

# Filter Python warnings
warnings.filterwarnings('ignore', category=DeprecationWarning, module='google.adk.tools.mcp_tool')
warnings.filterwarnings('ignore', message='.*EXPERIMENTAL.*')
warnings.filterwarnings('ignore', message='.*auth_config.*')

# Context manager to suppress MCP auth messages
class SuppressMCPOutput:
    """Context manager to suppress stdout/stderr from MCP toolset initialization."""
    def __enter__(self):
        self._original_stdout = sys.stdout
        self._original_stderr = sys.stderr
        sys.stdout = StringIO()
        sys.stderr = StringIO()
        return self

    def __exit__(self, exc_type, exc_val, exc_tb):
        sys.stdout = self._original_stdout
        sys.stderr = self._original_stderr
        return False

print("✅ Imports successful!")
print("   Key import: McpToolset for connecting to MCP servers")
print("   Output suppression: Ready for clean MCP toolset creation")

# %% [markdown]
# # Our MCP Servers
#
# Each MCP server is a standalone Python script that exposes a set of tools over the MCP protocol. Inside, it defines mock data (tickets, articles, systems) and functions that read or modify that data. ADK agents can then call these functions as tools without knowing the implementation details.
#
# We have 3 MCP servers for IT support:
#
# 1. **ticket_mcp_server.py** - Manages a database of support tickets
#    - Tools: `get_ticket`, `list_tickets`, `create_ticket`, `update_ticket`, `search_tickets`
# 2. **knowledge_mcp_server.py** - Stores IT help articles and guides
#    - Tools: `search_knowledge_base`, `get_article`, `list_articles`, `get_popular_articles`
# 3. **system_monitoring_mcp_server.py** - Tracks health of 5 servers (web, database, file, VPN, email)
#    - Tools: `check_system_health`, `list_all_systems`, `get_system_metrics`, `ping_system`, `get_system_logs`, `get_alerts`
#
# The cell below verifies that all three server files are present in the current directory:

# %%
# Ensure MCP server files are in the same directory as this notebook
from pathlib import Path

MCP_SERVERS = [
    "ticket_mcp_server.py",
    "knowledge_mcp_server.py",
    "system_monitoring_mcp_server.py"
]

print("🔍 Checking for MCP server files...\n")

# Verify files exist locally
all_found = True
for server_file in MCP_SERVERS:
    if Path(server_file).exists():
        print(f"✅ {server_file}")
    else:
        print(f"❌ {server_file} not found")
        all_found = False

if all_found:
    print("\n✅ All MCP servers ready to start!")
else:
    print("\n⚠️ Missing files detected!")
    print("📥 Please ensure all three .py files are in the same directory as this notebook")
    print("You can download them from: https://github.com/robertbarcik/ADK-tutorial")

# %% [markdown]
# # Connecting ADK Agents to MCP Servers
#
# When you create a `McpToolset`, ADK automatically launches the MCP server process, establishes stdio communication, discovers available tools, and manages the connection lifecycle. You only need to specify the command and script path.
#
# The key components are:
# - `McpToolset` - the main integration class that wraps an MCP server's tools for ADK
# - `StdioConnectionParams` / `StdioServerParameters` - configure how to launch and connect to the server
#
# Now let's create our three specialist agents, each connected to its own MCP server.
#
# ## Ticket Management Specialist
#
# This agent connects to the ticket MCP server and handles all ticket-related queries:

# %%
# Create McpToolset for ticket database
# Note: Suppressing auth messages since local MCP servers don't require authentication
with SuppressMCPOutput():
    ticket_toolset = McpToolset(
        connection_params=StdioConnectionParams(
            server_params=StdioServerParameters(
                command="python",
                args=["ticket_mcp_server.py"]
            )
        )
    )

# Create ticket specialist agent
ticket_specialist = LlmAgent(
    model=LiteLlm(model=f"openai/{OPENAI_MODEL}"),
    name="ticket_specialist",
    tools=[ticket_toolset],
    instruction="""
    You are a Ticket Management Specialist for IT support.

    YOUR CAPABILITIES:
    You can access the ticket database through MCP server tools:
    - Get ticket details by ID
    - List and filter tickets (by status, priority, team)
    - Create new tickets
    - Update ticket status and details
    - Search tickets by keywords

    YOUR ROLE:
    - Help users find and manage support tickets
    - Create tickets for new issues
    - Update ticket status as issues are resolved
    - Provide ticket summaries and analytics

    Always use the available tools to access real ticket data.
    Be concise and helpful in your responses.
    """
)

print("✅ Ticket Specialist Agent created!")
print(f"   Model: {OPENAI_MODEL}")
print(f"   Tools: Connected to Ticket Database MCP Server")
print(f"   Capabilities: CRUD operations on tickets")

# %% [markdown]
# ## Knowledge Base Specialist
#
# Same pattern as above. This agent connects to the knowledge base MCP server, which stores help articles and troubleshooting guides:

# %%
# Create McpToolset for knowledge base
with SuppressMCPOutput():
    knowledge_toolset = McpToolset(
        connection_params=StdioConnectionParams(
            server_params=StdioServerParameters(
                command="python",
                args=["knowledge_mcp_server.py"]
            )
        )
    )

# Create knowledge specialist agent
knowledge_specialist = LlmAgent(
    model=LiteLlm(model=f"openai/{OPENAI_MODEL}"),
    name="knowledge_specialist",
    tools=[knowledge_toolset],
    instruction="""
    You are a Knowledge Base Specialist for IT support.

    YOUR CAPABILITIES:
    You can access the knowledge base through MCP server tools:
    - Search documentation by keywords
    - Retrieve specific articles by ID
    - List articles by category
    - Find popular/helpful articles

    YOUR ROLE:
    - Help users find relevant documentation
    - Provide step-by-step guides for common issues
    - Recommend helpful articles
    - Answer questions using knowledge base content

    When users ask about IT issues:
    1. Search for relevant articles
    2. Retrieve full article content if needed
    3. Provide clear, actionable guidance
    4. Include article IDs for reference

    Always search the knowledge base first before answering.
    """
)

print("✅ Knowledge Specialist Agent created!")
print(f"   Model: {OPENAI_MODEL}")
print(f"   Tools: Connected to Knowledge Base MCP Server")
print(f"   Capabilities: Search and retrieve documentation")

# %% [markdown]
# ## System Monitoring Specialist
#
# The third specialist connects to the monitoring MCP server, which tracks the health of 5 servers in our infrastructure:

# %%
# Create McpToolset for system monitoring
with SuppressMCPOutput():
    monitoring_toolset = McpToolset(
        connection_params=StdioConnectionParams(
            server_params=StdioServerParameters(
                command="python",
                args=["system_monitoring_mcp_server.py"]
            )
        )
    )

# Create system specialist agent
system_specialist = LlmAgent(
    model=LiteLlm(model=f"openai/{OPENAI_MODEL}"),
    name="system_specialist",
    tools=[monitoring_toolset],
    instruction="""
    You are a System Monitoring Specialist for IT support.

    YOUR CAPABILITIES:
    You can monitor systems through MCP server tools:
    - Check system health and status
    - List all monitored systems
    - Get detailed metrics (CPU, memory, disk, network)
    - Ping systems to test connectivity
    - Retrieve system logs
    - Get active alerts

    YOUR ROLE:
    - Monitor system health
    - Diagnose performance issues
    - Identify system problems
    - Provide recommendations

    When asked about system issues:
    1. Check system health first
    2. Get relevant metrics if needed
    3. Check logs for errors
    4. Provide clear diagnosis and recommendations

    Alert Priority:
    - Critical: Immediate action required
    - Warning: Monitor closely, may need action
    - Healthy: No issues
    """
)

print("✅ System Specialist Agent created!")
print(f"   Model: {OPENAI_MODEL}")
print(f"   Tools: Connected to System Monitoring MCP Server")
print(f"   Capabilities: Health checks, metrics, logs")

# %% [markdown]
# # Building the Complete Multi-Agent System
#
# Now let's create a coordinator agent that routes requests to our MCP-connected specialists. This is the same hierarchical routing pattern from notebook 3, but now each specialist has real data access through MCP:

# %%
# Create IT Support Coordinator with all specialists
support_coordinator = LlmAgent(
    model=LiteLlm(model=f"openai/{OPENAI_MODEL}"),
    name="it_support_coordinator",
    sub_agents=[
        ticket_specialist,
        knowledge_specialist,
        system_specialist
    ],
    instruction="""
    You are the IT Support Coordinator.

    YOUR TEAM:
    You manage a team of specialists (these are your ONLY sub-agents):

    1. **ticket_specialist**: Manages support tickets
       - Use for: viewing, creating, updating tickets
       - Connected to ticket database via MCP
       - This specialist handles ALL ticket operations

    2. **knowledge_specialist**: Searches documentation
       - Use for: finding guides, troubleshooting steps
       - Connected to knowledge base via MCP

    3. **system_specialist**: Monitors system health
       - Use for: checking servers, diagnosing issues
       - Connected to monitoring system via MCP

    YOUR ROLE:
    1. Understand the user's request
    2. Route to the appropriate specialist(s)
    3. Coordinate multi-step workflows when needed
    4. Provide clear, helpful responses

    CRITICAL ROUTING RULES:
    - ONLY route to these three specialists: ticket_specialist, knowledge_specialist, system_specialist
    - NEVER try to route to team names (hardware_team, software_team, network_team, etc.)
    - When creating tickets, use ticket_specialist and pass team assignment as a parameter
    - Team names are DATA, not agents!

    ROUTING GUIDELINES:
    - Ticket questions → ticket_specialist
    - How-to questions → knowledge_specialist
    - System issues → system_specialist
    - Complex issues → multiple specialists in sequence

    WORKFLOW EXAMPLES:

    User: "What's the status of ticket T-1001?"
    → Route to ticket_specialist

    User: "How do I reset my password?"
    → Route to knowledge_specialist

    User: "Is the email server working?"
    → Route to system_specialist

    User: "Create a ticket for mouse issue, assign to hardware team"
    → Route to ticket_specialist (it will handle the team assignment)

    User: "Create a ticket for the email server issue"
    → 1. system_specialist (check email server)
    → 2. ticket_specialist (create ticket with details)

    Always be helpful, professional, and efficient.
    Remember: You can ONLY transfer to ticket_specialist, knowledge_specialist, or system_specialist!
    """
)

print("✅ IT Support Coordinator Agent created!")
print(f"   Model: {OPENAI_MODEL}")
print(f"   Sub-agents: 3 specialists")
print(f"   Capabilities: Complete IT support system")
print(f"\n🏗️  Architecture:")
print(f"   Coordinator (ADK) → Specialists (ADK) → MCP Servers → Data")

# %% [markdown]
# ## Runner and Session Service
#
# The runner connects the coordinator to a session service. All user messages go through the coordinator first, which then routes them to the right specialist:

# %%
# Create session service and runner
session_service = InMemorySessionService()
APP_NAME = "it_support_mcp_system"

runner = Runner(
    app_name=APP_NAME,
    agent=support_coordinator,
    session_service=session_service
)

print("✅ Runner initialized!")
print(f"   App: {APP_NAME}")
print(f"   Ready to handle IT support requests")

# %% [markdown]
# ## Helper Function
#
# This function sends a question to the coordinator, collects all events from the agent pipeline, and prints the final response:

# %%
# Track active sessions
_sessions = set()

async def ask_support(question: str, session_id: str = "support_session"):
    """
    Ask the IT support system a question.
    """
    user_id = "user_001"

    # Create session if needed
    session_key = (session_id, user_id)
    if session_key not in _sessions:
        await session_service.create_session(
            app_name=APP_NAME,
            user_id=user_id,
            session_id=session_id,
            state={}
        )
        _sessions.add(session_key)

    # Create message
    content = types.Content(role='user', parts=[types.Part(text=question)])

    print(f"\n{'='*80}")
    print(f"❓ USER QUESTION")
    print(f"{'='*80}")
    print(f"{question}")
    print(f"\n⏳ Processing (Coordinator → Specialists → MCP Servers)...\n")

    # Suppress MCP auth messages during agent execution
    # Save original streams
    original_stdout = sys.stdout
    original_stderr = sys.stderr

    # Create a custom stdout that filters out auth messages
    class FilteredOutput:
        def __init__(self, original_stream):
            self.original_stream = original_stream
            self.buffer = ""

        def write(self, text):
            # Filter out auth_config messages
            if "auth_config" not in text and "Will skip authentication" not in text and "FunctionTool instead" not in text:
                self.original_stream.write(text)
            return len(text)

        def flush(self):
            self.original_stream.flush()

    # Apply filtered output
    sys.stdout = FilteredOutput(original_stdout)
    sys.stderr = FilteredOutput(original_stderr)

    try:
        # Run agent with filtered output
        events = runner.run_async(user_id=user_id, session_id=session_id, new_message=content)

        # Process events
        final_response = None
        async for event in events:
            if event.is_final_response():
                final_response = event.content.parts[0].text
    finally:
        # Always restore original streams
        sys.stdout = original_stdout
        sys.stderr = original_stderr

    if final_response:
        print(f"\n{'='*80}")
        print(f"💬 SUPPORT RESPONSE")
        print(f"{'='*80}")
        print(final_response)
        print(f"{'='*80}\n")

    return final_response

print("✅ Helper function ready!")
print("   Use: await ask_support('your question here')")
print("   Note: Auth messages are filtered during execution")

# %% [markdown]
# # Testing the Complete System
#
# Let's test our complete ADK + MCP system with different types of requests.
#
# ## Test 1: Ticket Management
#
# The coordinator should route ticket queries to the ticket specialist, which calls the ticket MCP server:

# %%
# Ask about a specific ticket
await ask_support("What's the status of ticket T-1001?");

# %% [markdown]
# Now we ask for a filtered list. The ticket specialist should call the `list_tickets` tool with a priority filter:

# %%
# List high priority tickets
await ask_support("Show me all high priority tickets");

# %% [markdown]
# ## Test 2: Knowledge Base Search
#
# The coordinator should route how-to questions to the knowledge specialist:

# %%
# Search for password reset guide
await ask_support("How do I reset my password?");

# %% [markdown]
# A different type of question. The knowledge specialist should search for Wi-Fi troubleshooting articles:

# %%
# Search for WiFi troubleshooting
await ask_support("My WiFi keeps disconnecting, what should I do?");

# %% [markdown]
# ## Test 3: System Monitoring
#
# The coordinator should route system health queries to the monitoring specialist. We ask about a specific server by its ID from the monitoring database:

# %%
# Check email server health
await ask_support("Check the health status of email-server-01");

# %% [markdown]
# Instead of checking a specific system, we ask for all critical alerts across the infrastructure:

# %%
# Get all critical alerts
await ask_support("Show me all critical system alerts");

# %% [markdown]
# ## Test 4: Multi-Agent Workflow
#
# This is a more complex request that requires the coordinator to involve multiple specialists. It should check system health first, then search for documentation, and finally create a ticket:

# %%
# Complex request: check system + find docs + create ticket
await ask_support(
    "The file server seems slow. Can you check its status, find troubleshooting docs, "
    "and create a ticket if there's an issue?"
);

# %% [markdown]
# ## Test 5: Creating a New Ticket
#
# The ticket specialist can also create new tickets. The coordinator should recognize this as a ticket operation and route it accordingly:

# %%
# Create a new ticket
await ask_support(
    "Create a ticket: My mouse is not working properly. It keeps freezing. "
    "Priority: medium, assign to hardware team."
);

# %% [markdown]
# # Architecture Overview
#
# Here's the full request flow through the stack, using a ticket query as an example:
#
# ```
# User: "What's the status of ticket T-1001?"
#   ↓
# Coordinator Agent (ADK) → uses LLM to understand intent → routes to ticket_specialist
#   ↓
# Ticket Specialist (ADK) → uses LLM to decide tool → calls get_ticket via McpToolset
#   ↓
# McpToolset → sends tool call to ticket_mcp_server.py via stdio
#   ↓
# Ticket MCP Server → looks up ticket in database → returns JSON
#   ↓
# (response flows back up through the same layers)
#   ↓
# User receives: "Ticket T-1001: Laptop won't boot (Status: Open, Priority: High)"
# ```
#
# Each layer has a clear job:
#
# | Layer | Purpose | In Our System |
# |-------|---------|---------------|
# | **Reasoning** | Understand intent, make decisions | OpenAI gpt-5-nano |
# | **Orchestration** | Coordinate agents, manage workflows | ADK coordinator + specialists |
# | **Connectivity** | Standardized data access | 3 MCP servers |
# | **Data** | Actual data storage | In-memory dicts (demo) |

# %% [markdown]
# # Exercises
#
# ## Exercise 1: Create a New MCP Server (Intermediate)
#
# **Task:** Create a simple User Directory MCP server.
#
# **Requirements:**
# 1. Create `user_directory_mcp_server.py`
# 2. Store employee data (name, email, department, phone)
# 3. Implement tools: `search_employee`, `get_employee`, `list_by_department`
# 4. Follow MCP server pattern from existing servers
#
# **Bonus:** Connect it to the coordinator agent!

# %%
# Exercise 1: Your code here

# TODO: Create user_directory_mcp_server.py
# TODO: Start the server
# TODO: Create McpToolset for user directory
# TODO: Create a user_directory_specialist agent
# TODO: Add to coordinator's sub_agents

# %% [markdown]
# ## Exercise 2: Build a Report Generator (Advanced)
#
# **Task:** Create an agent that generates IT support reports.
#
# **Requirements:**
# 1. Create a `report_generator` agent
# 2. Access multiple MCP servers (tickets + systems)
# 3. Generate reports: open tickets summary, critical system alerts, team workload
# 4. Format output nicely
#
# **Hint:** Use multiple `McpToolset` instances in one agent!

# %%
# Exercise 2: Your code here

# TODO: Create report generator agent with multiple toolsets
# report_agent = LlmAgent(
#     model=LiteLlm(model=f"openai/{OPENAI_MODEL}"),
#     name="report_generator",
#     tools=[ticket_toolset, monitoring_toolset],  # Multiple MCP servers!
#     instruction="..."
# )

# %% [markdown]
# ## Exercise 3: Implement Auto-Escalation (Advanced)
#
# **Task:** Create a workflow that auto-escalates critical issues.
#
# **Requirements:**
# 1. Monitor for critical system alerts
# 2. Automatically create high-priority tickets
# 3. Search knowledge base for relevant docs
# 4. Include all info in ticket description
#
# **Hint:** Use `SequentialAgent` or create custom workflow logic!

# %%
# Exercise 3: Your code here

# TODO: Create auto-escalation workflow
# Steps:
# 1. Check for critical alerts (system_specialist)
# 2. For each alert, search KB (knowledge_specialist)
# 3. Create ticket with alert + KB info (ticket_specialist)
# 4. Consider using SequentialAgent or LoopAgent

# %% [markdown]
# # Key Takeaways
#
# This notebook completes the ADK tutorial series. Here's a summary of all six notebooks:
#
# | Notebook | Topic | Key Concept |
# |----------|-------|-------------|
# | 1. ADK Basics | Simple agent | `LlmAgent`, `Runner`, `SessionService` |
# | 2. Tools | Function calling | Tools with type hints + docstrings |
# | 3. Multi-Agent | Hierarchical routing | `sub_agents`, coordinator + specialists |
# | 4. Workflows | Sequential + Parallel | `SequentialAgent`, `ParallelAgent` |
# | 5. Hybrid | Rules + LLMs | `BaseAgent`, `LoopAgent`, cost optimization |
# | 6. MCP Integration | Complete stack | `McpToolset`, three-layer architecture |
#
# The key production principles across all notebooks:
#
# 1. **Right tool for the job** - rules for simple decisions, LLMs for complex reasoning
# 2. **Separation of concerns** - each agent/server has one clear responsibility
# 3. **Composability** - build complex systems from simple, reusable pieces
# 4. **Cost awareness** - use the cheapest approach that meets your quality requirements
#
# ## Resources
#
# - [ADK Official Documentation](https://google.github.io/adk-docs/)
# - [ADK MCP Integration](https://google.github.io/adk-docs/tools/mcp-tools/)
# - [MCP Specification](https://modelcontextprotocol.io/)
# - [MCP Python SDK](https://github.com/modelcontextprotocol/python-sdk)
# - [ADK Examples](https://github.com/google/adk-examples)

# %% [markdown]
# # Cleanup
#
# MCP servers are managed automatically by `McpToolset` - no manual cleanup needed.

# %%
# No manual cleanup needed!
# McpToolset automatically manages MCP server lifecycle

print("✅ Session completed!")
print("   MCP servers will be automatically cleaned up by ADK")
print("   Session data cleared from memory")
